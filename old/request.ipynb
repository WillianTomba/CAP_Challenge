# %%
import requests
import pandas as pd

# URL da API
url = "https://api.openligadb.de/getmatchdata/67522"

# Fazendo a requisição para a API
response = requests.get(url)

# Verificando se a requisição foi bem-sucedida
if response.status_code == 200:
    data = response.json()
    print("Dados extraídos com sucesso!")
else:
    print(f"Erro na requisição: {response.status_code}")
    data = []

# Convertendo os dados para um DataFrame do Pandas
data
# Out:
# Dados extraídos com sucesso!
# {'matchID': 67522,
#  'matchDateTime': '2023-08-12T09:00:00',
#  'timeZoneID': 'W. Europe Standard Time',
#  'leagueId': 4640,
#  'leagueName': 'FIFA Women´s World Cup 2023',
#  'leagueSeason': 2023,
#  'leagueShortcut': 'wwc',
#  'matchDateTimeUTC': '2023-08-12T07:00:00Z',
#  'group': {'groupName': 'Quarterfinals', 'groupOrderID': 5, 'groupID': 42199},
#  'team1': {'teamId': 6035,
#   'teamName': 'Australien Frauen',
#   'shortName': 'AUS',
#   'teamIconUrl': 'http://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Flag_of_Australia.svg/20px-Flag_of_Australia.svg.png',
#   'teamGroupName': None},
#  'team2': {'teamId': 6046,
#   'teamName': 'Frankreich Frauen',
#   'shortName': 'FRA',
#   'teamIconUrl': 'http://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png',
#   'teamGroupName': None},
#  'lastUpdateDateTime': '2023-10-05T22:12:25.643',
#  'matchIsFinished': True,
#  'matchResults': [{'resultID': 103345,
#    'resultName': 'Halbzeit',
#    'pointsTeam1': 0,
#    'pointsTeam2': 0,
#    'resultOrderID': 1,
#    'resultTypeID': 1,
#    'resultDescription': None},
#   {'resultID': 103344,
#    'resultName': 'Endergebnis',
#    'pointsTeam1': 7,
#    'pointsTeam2': 6,
#    'resultOrderID': 2,
#    'resultTypeID': 2,
#    'resultDescription': 'result after regular time'},
#   {'resultID': 103348,
#    'resultName': 'nach Elfmeterschießen',
#    'pointsTeam1': 7,
#    'pointsTeam2': 6,
#    'resultOrderID': 4,
#    'resultTypeID': 5,
#    'resultDescription': 'penalties'}],
#  'goals': [{'goalID': 102386,
#    'scoreTeam1': 1,
#    'scoreTeam2': 0,
#    'matchMinute': None,
#    'goalGetterID': 20151,
#    'goalGetterName': 'Caitlin Foord',
#    'isPenalty': True,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102387,
#    'scoreTeam1': 1,
#    'scoreTeam2': 1,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': True,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102388,
#    'scoreTeam1': 1,
#    'scoreTeam2': 2,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': True,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102389,
#    'scoreTeam1': 2,
#    'scoreTeam2': 2,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102390,
#    'scoreTeam1': 2,
#    'scoreTeam2': 3,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102391,
#    'scoreTeam1': 3,
#    'scoreTeam2': 3,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102392,
#    'scoreTeam1': 3,
#    'scoreTeam2': 4,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102393,
#    'scoreTeam1': 4,
#    'scoreTeam2': 4,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102394,
#    'scoreTeam1': 4,
#    'scoreTeam2': 5,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102395,
#    'scoreTeam1': 5,
#    'scoreTeam2': 5,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102396,
#    'scoreTeam1': 5,
#    'scoreTeam2': 6,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102397,
#    'scoreTeam1': 6,
#    'scoreTeam2': 6,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None},
#   {'goalID': 102398,
#    'scoreTeam1': 7,
#    'scoreTeam2': 6,
#    'matchMinute': None,
#    'goalGetterID': 0,
#    'goalGetterName': '',
#    'isPenalty': False,
#    'isOwnGoal': False,
#    'isOvertime': False,
#    'comment': None}],
#  'location': None,
#  'numberOfViewers': None}
